# %% [markdown]
# This notebook runs the baseline on different parts and axes
#
#         dic = {
#                     'LHAx': (18*125, 18*125 + 125),
#                     'LLAx': (36*125, 36*125 + 125),
#                     'RHAx': (125*9, 125*9 + 125),
#                     'RLAx': (27*125, 287*125 + 125),
#                     'CAx' : (125*0, 125*0 + 125),
#                     'LHAy': (19*125, 19*125 + 125),
#                     'LLAy': (37*125, 37*125 + 125),
#                     'RHAy': (125*10, 125*10 + 125),
#                     'RLAy': (28*125, 28*125 + 125),
#                     'CAy' : (125*1, 125*1 + 125),
#                     'LHAz': (20*125, 20*125 + 125),
#                     'LLAz': (38*125, 38*125 + 125),
#                     'RHAz': (125*11, 125*11 + 125),
#                     'RLAz': (29*125, 29*125 + 125),
#                     'CAz' : (125*2, 125*2 + 125),
#
#             }

# %%
from copy import deepcopy
from mlp.layers import MLP, Linear, Sigmoid, Softmax #import required layer types
from mlp.layers import * 
from mlp.optimisers import SGDOptimiser #import the optimiser

from mlp.costs import CECost, MSECost #import the cost we want to use for optimisation
from mlp.schedulers import LearningRateFixed
import numpy
import logging
from mlp.dataset import *
from base import *

# %%
# right arm y
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.info('Initialising data providers...')

train_dp = MACLDataProvider(dset='train', batch_size=100,
                            max_num_batches=-10, randomize=True,name='LHAx')
valid_dp = MACLDataProvider(dset='valid', batch_size=1824,
                            max_num_batches=1, randomize=False,name='LHAx')



logger = logging.getLogger()
logger.setLevel(logging.INFO)
rng = numpy.random.RandomState([2015,10,10])
# Out:
# INFO:root:Initialising data providers...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-817cc647c7d3> in <module>()
#       5
#       6 train_dp = MACLDataProvider(dset='train', batch_size=100,
# ----> 7                             max_num_batches=-10, randomize=True,name='LHAx')
#       8 valid_dp = MACLDataProvider(dset='valid', batch_size=1824,
#       9                             max_num_batches=1, randomize=False,name='LHAx')
#
# /home/francisco/hons2/HonsProOpen/MLPHonoursExtension/mlp/dataset.pyc in __init__(self, dset, batch_size, max_num_batches, max_num_examples, randomize, rng, conv_reshape, name, fft)
#     140
#     141         with gzip.open(dset_path) as f:
# --> 142             x, t = cPickle.load(f)
#     143             print x.shape , t.shape
#     144
#
# /usr/lib/python2.7/gzip.pyc in readline(self, size)
#     453         bufs = []
# ...

# %%
base(train_dp, valid_dp, rng, logger)
# Out:
# INFO:root:Training started...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for initial model is 15.570. Accuracy is 1.44%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for initial model is 15.654. Accuracy is 0.93%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 12.230. Accuracy is 19.49%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 4.052. Accuracy is 24.56%
# INFO:mlp.optimisers:Epoch 1: Took 0 seconds. Training speed 45006 pps. Validation speed 182500 pps.
# INFO:mlp.optimisers:Epoch 2: Training cost (ce) is 4.831. Accuracy is 27.96%
# INFO:mlp.optimisers:Epoch 2: Validation cost (ce) is 3.898. Accuracy is 26.48%
# INFO:mlp.optimisers:Epoch 2: Took 0 seconds. Training speed 45006 pps. Validation speed 182500 pps.
# INFO:mlp.optimisers:Epoch 3: Training cost (ce) is 2.992. Accuracy is 34.97%
# INFO:mlp.optimisers:Epoch 3: Validation cost (ce) is 2.231. Accuracy is 37.55%
# ...

# %%
# right arm y
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.info('Initialising data providers...')

train_dp = MACLDataProvider(dset='train', batch_size=100,
                            max_num_batches=-10, randomize=True,name='CAx')
valid_dp = MACLDataProvider(dset='valid', batch_size=1824,
                            max_num_batches=1, randomize=False,name='CAx')



logger = logging.getLogger()
logger.setLevel(logging.INFO)
rng = numpy.random.RandomState([2015,10,10])
# Out:
# INFO:root:Initialising data providers...
# (7296, 45, 125) (7296,)
# (7296, 125)
# (1824, 45, 125) (1824,)
# (1824, 125)

# %%
base(train_dp, valid_dp, rng, logger)
# Out:
# INFO:root:Training started...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for initial model is 17.116. Accuracy is 4.88%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for initial model is 16.885. Accuracy is 4.55%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 13.613. Accuracy is 18.78%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 4.280. Accuracy is 28.23%
# INFO:mlp.optimisers:Epoch 1: Took 0 seconds. Training speed 45006 pps. Validation speed 182500 pps.
# INFO:mlp.optimisers:Epoch 2: Training cost (ce) is 2.665. Accuracy is 30.64%
# INFO:mlp.optimisers:Epoch 2: Validation cost (ce) is 2.273. Accuracy is 33.55%
# INFO:mlp.optimisers:Epoch 2: Took 0 seconds. Training speed 45006 pps. Validation speed 182500 pps.
# INFO:mlp.optimisers:Epoch 3: Training cost (ce) is 1.926. Accuracy is 39.29%
# INFO:mlp.optimisers:Epoch 3: Validation cost (ce) is 1.897. Accuracy is 39.80%
# ...

# %%
# right arm y
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.info('Initialising data providers...')

train_dp = MACLDataProvider(dset='train', batch_size=100,
                            max_num_batches=-10, randomize=True,name='RHAx')
valid_dp = MACLDataProvider(dset='valid', batch_size=1824,
                            max_num_batches=1, randomize=False,name='RHAx')



logger = logging.getLogger()
logger.setLevel(logging.INFO)
rng = numpy.random.RandomState([2015,10,10])

# %%
# right arm y
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.info('Initialising data providers...')

train_dp = MACLDataProvider(dset='train', batch_size=100,
                            max_num_batches=-10, randomize=True,name='RLAx')
valid_dp = MACLDataProvider(dset='valid', batch_size=1824,
                            max_num_batches=1, randomize=False,name='RLAx')



logger = logging.getLogger()
logger.setLevel(logging.INFO)
rng = numpy.random.RandomState([2015,10,10])

# %%
#some hyper-parameters
nhid = 100
learning_rate = 0.01
max_epochs = 1000
cost = CECost()
    
stats = list()

test_dp = deepcopy(valid_dp)
train_dp.reset()
valid_dp.reset()
test_dp.reset()

# NETWORK TOPOLOGY:
model = MLP(cost=cost)
model.add_layer(Relu(idim=125, odim=125, irange=1.6, rng=rng))
model.add_layer(Softmax(idim=125, odim=19, rng=rng))

# define the optimiser, here stochasitc gradient descent
# with fixed learning rate and max_epochs
lr_scheduler = LearningRateFixed(learning_rate=learning_rate, max_epochs=max_epochs)
optimiser = SGDOptimiser(lr_scheduler=lr_scheduler)

logger.info('Training started...')
tr_stats_b, valid_stats_b = optimiser.train(model, train_dp, valid_dp)

logger.info('Testing the model on test set:')

tst_cost, tst_accuracy = optimiser.validate(model,test_dp )
logger.info('ACL test set accuracy is %.2f %%, cost (%s) is %.3f'%(tst_accuracy*100., cost.get_name(), tst_cost))

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.info('Initialising data providers...')
rng = numpy.random.RandomState([2015,10,10])

train_dp = MACLDataProvider(dset='train', batch_size=100, max_num_batches=7980,
                            randomize=True, conv_reshape=True, fft=True, name='RLAx')
valid_dp = MACLDataProvider(dset='valid', batch_size=100, max_num_batches=-10,
                            randomize=False, conv_reshape=True, fft=True, name='RLAx')
# Out:
# INFO:root:Initialising data providers...
# (7980, 45, 125) (7980,)
# (7980, 125)
# (1140, 45, 125) (1140,)
# (1140, 125)

# %%
rn = numpy.random.RandomState(10)
W = rn.uniform(
            -1.6, 1.6,
            (125, 125))
W
# Out:
# array([[ 0.86822606, -1.53359376,  0.42767435, ..., -1.25798533,
#          0.78273037, -0.09668706],
#        [ 0.31441815, -1.12761538, -1.01108857, ..., -1.40783934,
#          1.56453432, -0.86789653],
#        [ 0.36704548, -0.42231462,  0.968883  , ..., -0.07460809,
#          0.18118622, -0.18964142],
#        ...,
#        [-0.0428424 , -0.64352417,  0.25391824, ...,  1.25314143,
#         -0.39344749, -0.35314173],
#        [ 0.83318823, -0.08169945,  0.0147344 , ...,  1.23596848,
#          0.72130843, -0.54105238],
#        [ 0.29795466,  1.38554989, -1.0312863 , ..., -1.57873026,
#         -1.18787821, -0.73780853]])

# %%
base(train_dp, valid_dp, logger=logger,learning_rate=0.007)
# Out:
# [[-0.07450698  0.10177284  1.42131424 ..., -0.13237586  0.80121394
#   -1.28483278]
#  [-0.35145398 -0.75895416 -1.04686202 ..., -0.08511088 -0.34216327
#    1.18005952]
#  [ 0.83697577  1.45040705 -0.09855184 ..., -1.12794658 -0.13785745
#    1.28074692]
#  ...,
#  [ 0.31439714  1.39275777 -0.68956947 ..., -0.19970518  1.45919736
#   -0.83727053]
#  [ 1.27457932 -0.73769169 -0.78124216 ...,  1.07851653  1.09304173
#   -0.18548291]
#  [ 0.8632237  -0.66431037 -1.54016636 ..., -1.33460195 -0.38614275
#    0.43675598]]
#
# [[ 0.0855959   0.04619147 -0.06111496 ..., -0.03578707 -0.09689945
#   -0.09726774]
#  [-0.02569398 -0.04627598  0.0383601  ..., -0.01237021 -0.02243649
#   -0.08167041]
#  [ 0.02432366  0.00626292  0.01502459 ..., -0.00489601 -0.01968733
#    0.06870147]
#  ...,
#  [ 0.02332834 -0.06131559 -0.03909237 ..., -0.05800693  0.05470842
#    0.08880502]
#  [ 0.01672316 -0.05055901 -0.01964499 ..., -0.06073479 -0.04186922
#    0.09990075]
# ...

# %%
from mlp.layers import Relu
from mlp.convlin import *

rng = numpy.random.RandomState([2016,02,26])

cost = CECost()
model = MLP(cost=cost)
model.add_layer(ConvRelu_Opt(1, 1, rng=rng, stride=(1,1)))
# model.add_layer(ConvMaxPool2D(5, (100,5, 24,24)))
# model.add_layer(ConvLinear_Opt(5, 10, rng=rng, image_shape=(12, 12) , kernel_shape=(5,5)))
# model.add_layer(ConvMaxPool2D(10, (100,10, 8,8), pool_shape=(2,2)))
# sigmoid 
model.add_layer(Sigmoid(idim=122, odim=122, rng=rng))

model.add_layer(Softmax(idim=122, odim=19, rng=rng))
# 0.01 was top notch 0.05 even more so 
lr_scheduler = LearningRateFixed(learning_rate=0.005, max_epochs=1000)
optimiser = SGDOptimiser(lr_scheduler=lr_scheduler)
val, tra = optimiser.train(model, train_dp, valid_dp)
# Out:
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for initial model is 3.005. Accuracy is 5.32%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for initial model is 3.026. Accuracy is 5.55%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 2.972. Accuracy is 6.82%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 2.982. Accuracy is 5.36%
# INFO:mlp.optimisers:Epoch 1: Took 0 seconds. Training speed 25487 pps. Validation speed 55050 pps.
# INFO:mlp.optimisers:Epoch 2: Training cost (ce) is 2.909. Accuracy is 8.87%
# INFO:mlp.optimisers:Epoch 2: Validation cost (ce) is 2.890. Accuracy is 10.09%
# INFO:mlp.optimisers:Epoch 2: Took 0 seconds. Training speed 24691 pps. Validation speed 55050 pps.
# INFO:mlp.optimisers:Epoch 3: Training cost (ce) is 2.770. Accuracy is 21.22%
# INFO:mlp.optimisers:Epoch 3: Validation cost (ce) is 2.705. Accuracy is 25.45%
# INFO:mlp.optimisers:Epoch 3: Took 0 seconds. Training speed 24691 pps. Validation speed 55050 pps.
# ...
